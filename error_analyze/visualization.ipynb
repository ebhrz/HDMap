# %%
from plot import *
# %matplotlib widget
# these .pkl data is generated by derivation.py, you can put your own intrinsic, extrinsic parameters and the ground truth point to visualize the error.

# %%
# LiDAR-Camera Extrinsic Parameter Errors Quantifying in the Image Domain

image_r = data_load("lane_image_gT_r.pkl")
plot_r(image_r,"Extrinsic Error Derivated in Image Domain - Rotation Error")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
image_t = data_load("lane_image_gT_t.pkl")
plot_t(image_t,"Extrinsic Error Derivated in Image Domain - Translation Error")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Error Quantifying for Vectorized Lane Lines in the 3D Domain

# # Semantic Segmentation Errors
it = data_load("image_gtT_gtK.pkl")
plot_i(it,"Semantic Segmentation Errors Derivated in 3D Domain")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# # LiDAR-Camera Extrinsic Parameter Errors
ex_r = data_load("T_r_gt.pkl")
plot_r(ex_r,"Extrinsic Error Derivated in 3D Domain - Rotation Error")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ex_t = data_load("T_t_gt.pkl")
plot_t(ex_t,"Extrinsic Error Derivated in 3D Domain - Translation Error")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
